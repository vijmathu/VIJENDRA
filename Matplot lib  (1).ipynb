# %%
### there are many cases in ML and data science where visualization are extremely important
### to understand the problem

# %%
### What you ususally do you get data , explore the data, preprocess the data, you train the model on the training
### data and finally evaluate the model use test data.
### We need graphically represention of the data to make more meaning and intutive understanding of the data
### certain patner emerges when we look at the graphs which can't be possible looking at tables & numbers

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import os

# %%
os.listdir()
# Out:
# ['.bashrc',
#  '.bash_logout',
#  '.profile',
#  'Matplot lib .ipynb',
#  '.local',
#  '.jupyter',
#  '.jupyter-server-log.txt',
#  '.cache',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.config',
#  'SuperStore.txt',
#  'SuperstoreNew.csv',
#  'README.md',
#  'Superstore1.csv',
#  'Superstore.csv',
#  'requirements.txt.txt',
#  '.git',
#  'Python Sep 1.ipynb',
#  'Untitled (1).ipynb',
#  'Sample.xls']

# %%
### we will design the scatter plot which require two varaible 

X_data=np.random.random(500)*100
Y_data=np.random.random(500)*100
plt.xlabel='Population'
plt.ylabel='GDP'

plt.scatter(X_data,Y_data,c='blue',marker='*',s=120,alpha=0.4)

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-learn

# %%
Data1=pd.read_csv('SuperstoreNew.csv',encoding='unicode_escape')

# %%
Data1.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class    DV-13045
# 3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
Data1.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
X1_label=Data1['Order Date']
Y1_label=Data1['Sales']

plt.plot(X1_label,Y1_label)
plt.show()
