# %% [markdown]
# #### pandas is a software library written for the Python programming language for data manipulation and analysis.
# #### In particular, it offers data structures and operations for manipulating numerical tables and time series.
# #### It is free software released under the three-clause BSD license.

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install panel
# !pip install bokeh
# !pip install scikit-learn
# !pip install streamlit
# !pip install plotly
# !pip install dash
# !pip install dash-renderer
# !pip install dash_html_components
# !pip install dash_core_components
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 23.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 28.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 31.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 32.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.7/300.7 kB 25.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 35.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.3 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 39.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 20.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 21.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 21.0 MB/s eta 0:00:0000:0100:01
# ...

# %%
## Import necessary libraries and setup the working directory
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/home/jovyan'

# %%
os.listdir()
# Out:
# ['.bashrc',
#  '.bash_logout',
#  '.profile',
#  '.local',
#  'CSC_LOGO_NEW.PNG',
#  '.jupyter',
#  'CSC_LOGO.jpg',
#  '.jupyter-server-log.txt',
#  'Python Sep 11.ipynb',
#  '.cache',
#  '.ipynb_checkpoints',
#  '.ipython',
#  'DashBoard.jpg',
#  'SuperStore.txt',
#  'SuperstoreNew.csv',
#  'README.md',
#  'Superstore1.csv',
#  'Matplot lib  (1).ipynb',
#  'Superstore.csv',
#  'requirements.txt.txt',
#  '.git',
#  'Python Sep 1.ipynb',
#  'Untitled (1).ipynb',
#  'Sample.xls']

# %%
Data= pd.read_csv('SuperstoreNew.csv',encoding='unicode_escape')

# %%
### First top 5 rows

Data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class    DV-13045
# 3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ##### Chapter :------------->2 Haow to select the series from the pandas dataframe

# %%
Data.dtypes

### Pandas create every series of the data frame into atttribute and it is very handy to use
### if you name the column which conflict with build in funtion and attibutes of the dataframe, it will not work........

### Two ways to select the series from the dataframe 1. Dot notation and 2. bracket notation [], this is always work......
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
#### How to create new series from the existing series of the dataframe

Data['Location']= Data.City+', '+ Data.State

# %%
Data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class    DV-13045
# 3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ##### <h3><u><font color='blue'><b>Chapter:------------> 3   WHy do some pandas  commands end with patnetheses and other commands don't </b></font></h3></u>

# %% [markdown]
# Data.describe(include=['int','float']) ### Some of the method required optional argument like describe
#
#
#
# ### Methods are action oriented,e.g talk,eat and attributes, e.g like height,eye_color are without parenthesis

# %% [markdown]
# ##### <h3><u><font color='green'><b>Chapter:---------->4 How do i change the columns name of the pandas dataframe</b></font></h3></u>

# %%
Data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Location'],
#       dtype='object')

# %%
Data.rename(columns={'Customer ID':'Customer_ID','Row ID':'Row_ID'},inplace=True)


### Rename method can be used to rename the columns name 
### inplace argument are used to tell to make the action to take place , i want to effect underline dataset

# %%
### Simplier way to change the columns names of the dataframe
### Create regulat python list.

### New_Col_Name=['','','','']
#### Data.columns=New_Col_Name

# %%
## While reading the file , we can change the columns name

### pd.read_csv(,names=New_Col_Name.header=0)

### Read the documentation for futher details

## Bonus tip,suppose you have 100 columns and you want to replace the space between the columns name usind 
#### "rename methods"

# %%
Data.columns=Data.columns.str.replace(' ', '_')

# %%
Data.columns
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Location'],
#       dtype='object')

# %% [markdown]
# ##### <h3><u><font color='red'><b>Chapter:---------> 5 How to remove columns from a pandas DataFrame</b></font></h3></u>

# %%
## In order to drop a column from the dataframe,, use drop() method.

Data.shape
# Out:
# (9994, 22)

# %%
### Axis 0=row ,,Axis 1= columns

# %%
Data.drop('Sales',axis=1,inplace=True)

# %%
Data.shape
# Out:
# (9994, 21)

# %%
#### to delete multiple column we can pass a list of columns 

Data.drop(['Discount','Quantity'],axis=1,inplace=True)

# %%
Data.shape
# Out:
# (9994, 19)

# %%
### what if we need to drop a row rather than a column 

Data.drop(index=[0,1],axis=0,inplace=True)

# %%
Data.head()

### to check the row are drop
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class    DV-13045
# 3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 5       6  CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
# 6       7  CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
#
#      Customer_Name    Segment        Country             City       State  \
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 5  Brosina Hoffman   Consumer  United States      Los Angeles  California
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  California
#
# ...

# %% [markdown]
# ##### <h3><u><font color='orange'><b>Chapter:---------> 6 How do i sort pandas Dataframe or series</b></font></h3></u>

# %% [markdown]
# <img src="CSC_LOGO.jpg" width="200" height="50">
# <img src="DashBoard.jpg" width="500" height="200">

# %%
Data.dtypes
# Out:
# Row_ID             int64
# Order_ID          object
# Order_Date        object
# Ship_Date         object
# Ship_Mode         object
# Customer_ID       object
# Customer_Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal_Code        int64
# Region            object
# Product_ID        object
# Category          object
# Sub-Category      object
# Product_Name      object
# Profit           float64
# Location          object
# dtype: object

# %%
Data.head(2)
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class    DV-13045
# 3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal_Code Region       Product_ID         Category Sub-Category  \
# 2        90036   West  OFF-LA-10000240  Office Supplies       Labels
# 3        33311  South  FUR-TA-10000577        Furniture       Tables
#
#                                         Product_Name    Profit  \
# 2  Self-Adhesive Address Labels for Typewriters b...    6.8714
# 3      Bretford CR4500 Series Slim Rectangular Table -383.0310
#
#                    Location
# 2   Los Angeles, California
# 3  Fort Lauderdale, Florida

# %%
Data.Customer_Name.sort_values(ascending=False)
# Out:
# 5898    Zuschuss Donatelli
# 3040    Zuschuss Donatelli
# 5897    Zuschuss Donatelli
# 3815    Zuschuss Donatelli
# 3814    Zuschuss Donatelli
#                ...
# 8802         Aaron Bergman
# 4961         Aaron Bergman
# 8222         Aaron Bergman
# 8801         Aaron Bergman
# 4963         Aaron Bergman
# Name: Customer_Name, Length: 9992, dtype: object

# %%
### TO keep the entire data frame along with sorting has done.

Data.sort_values('Customer_Name').head(4)
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 4963    4964  CA-2014-156587  07-03-2014  08-03-2014     First Class
# 8222    8223  CA-2014-152905  18-02-2014  24-02-2014  Standard Class
# 8801    8802  CA-2016-140935  10-11-2016  12-11-2016     First Class
# 4962    4963  CA-2014-156587  07-03-2014  08-03-2014     First Class
#
#      Customer_ID  Customer_Name   Segment        Country           City  \
# 4963    AB-10015  Aaron Bergman  Consumer  United States        Seattle
# 8222    AB-10015  Aaron Bergman  Consumer  United States      Arlington
# 8801    AB-10015  Aaron Bergman  Consumer  United States  Oklahoma City
# 4962    AB-10015  Aaron Bergman  Consumer  United States        Seattle
#
#            State  Postal_Code   Region       Product_ID         Category  \
# 4963  Washington        98103     West  OFF-ST-10002344  Office Supplies
# 8222       Texas        76017  Central  OFF-ST-10000321  Office Supplies
# ...

# %%
### Sort by many columns

Data.sort_values(['Customer_Name','City']).head()
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 8222    8223  CA-2014-152905  18-02-2014  24-02-2014  Standard Class
# 8801    8802  CA-2016-140935  10-11-2016  12-11-2016     First Class
# 8802    8803  CA-2016-140935  10-11-2016  12-11-2016     First Class
# 4961    4962  CA-2014-156587  07-03-2014  08-03-2014     First Class
# 4962    4963  CA-2014-156587  07-03-2014  08-03-2014     First Class
#
#      Customer_ID  Customer_Name   Segment        Country           City  \
# 8222    AB-10015  Aaron Bergman  Consumer  United States      Arlington
# 8801    AB-10015  Aaron Bergman  Consumer  United States  Oklahoma City
# 8802    AB-10015  Aaron Bergman  Consumer  United States  Oklahoma City
# 4961    AB-10015  Aaron Bergman  Consumer  United States        Seattle
# 4962    AB-10015  Aaron Bergman  Consumer  United States        Seattle
#
#            State  Postal_Code   Region       Product_ID         Category  \
# ...

# %% [markdown]
# ##### <h3><u><font color='orchid'><b>Chapter:---------> 7 How do i filter rows of the pandas Data frame by columns value</b></font></h3></u>

# %%
Data.shape
# Out:
# (9992, 19)

# %%
Data.dtypes
# Out:
# Row_ID             int64
# Order_ID          object
# Order_Date        object
# Ship_Date         object
# Ship_Mode         object
# Customer_ID       object
# Customer_Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal_Code        int64
# Region            object
# Product_ID        object
# Category          object
# Sub-Category      object
# Product_Name      object
# Profit           float64
# Location          object
# dtype: object

# %%
Data.filter(items=['City','Profit'],axis=1).describe()
# Out:
#             Profit
# count  9992.000000
# mean     28.636462
# std     234.275729
# min   -6599.978000
# 25%       1.728000
# 50%       8.652800
# 75%      29.359500
# max    8399.976000

# %%
Data.shape
# Out:
# (9992, 19)

# %%
Data1= pd.read_csv('SuperstoreNew.csv',encoding='unicode_escape')

# %%
Data1.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
Data1[(Data1.Profit>100) | (Data1.Sales>800)].head()
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 1        2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 3        4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 7        8  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 10      11  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 11      12  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
#
#    Customer ID    Customer Name   Segment        Country             City  \
# 1     CG-12520      Claire Gute  Consumer  United States        Henderson
# 3     SO-20335   Sean O'Donnell  Consumer  United States  Fort Lauderdale
# 7     BH-11710  Brosina Hoffman  Consumer  United States      Los Angeles
# 10    BH-11710  Brosina Hoffman  Consumer  United States      Los Angeles
# 11    BH-11710  Brosina Hoffman  Consumer  United States      Los Angeles
#
#     ... Postal Code  Region       Product ID    Category Sub-Category  \
# ...

# %%
#### & sign means both conditiion should fulfil
#### | sign means one of the condition should fulfil

# %% [markdown]
# ##### <h3><u><font color='Tomato  '><b>Chapter:---------> 8 How do i apply  multiple filters criteria to a pandas dataframe</b></font></h3></u>

# %%
### Logical operator 
## Operator           Description                                                    Example
## and             Returns True if both statements are true                    x < 5 and x < 10
## or              Returns True if one of the statements is true               x < 5 or x < 4
## not             Reverse the result, returns False if the result is true     not(x < 5 and x < 10)

# %%
True or True
# Out:
# True

# %%
Data1[(Data1.Profit>100) & (Data1.Quantity>11)].head()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 251      252  CA-2016-145625  11-09-2016  17-09-2016  Standard Class
# 1013    1014  US-2015-126214  21-12-2015  24-12-2015    Second Class
# 1048    1049  CA-2014-139192  27-05-2014  01-06-2014    Second Class
# 1246    1247  CA-2014-168494  12-12-2014  14-12-2014    Second Class
# 1250    1251  CA-2017-115602  18-12-2017  24-12-2017  Standard Class
#
#      Customer ID    Customer Name   Segment        Country           City  \
# 251     KC-16540  Kelly Collister  Consumer  United States      San Diego
# 1013    JS-15880   John Stevenson  Consumer  United States        Seattle
# 1048    LC-16885   Lena Creighton  Consumer  United States  San Francisco
# 1246    NP-18700       Nora Preis  Consumer  United States         Fresno
# 1250    DJ-13630      Doug Jacobs  Consumer  United States  New York City
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
#### Simply multiple or and &  using "isin" series method, pass a list to get the desired list 


Data1[(Data1.Sales>10) & (Data1.Category.isin(['Technology','Furniture']))].head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 5       6  CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
# 7       8  CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
#
#      Customer Name   Segment        Country             City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States        Henderson  ...       42420
# 1      Claire Gute  Consumer  United States        Henderson  ...       42420
# 3   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 5  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
# 7  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
#
# ...

# %% [markdown]
# ##### <h3><u><font color='Sienna'><b>Chapter:---------> 9 Your Pandas Question answered</b></font></h3></u>

# %%
Data1.filter(items=['City','Sales'])
# Out:
#                  City     Sales
# 0           Henderson  261.9600
# 1           Henderson  731.9400
# 2         Los Angeles   14.6200
# 3     Fort Lauderdale  957.5775
# 4     Fort Lauderdale   22.3680
# ...               ...       ...
# 9989            Miami   25.2480
# 9990       Costa Mesa   91.9600
# 9991       Costa Mesa  258.5760
# 9992       Costa Mesa   29.6000
# 9993      Westminster  243.1600
#
# [9994 rows x 2 columns]

# %%
Data1.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
### Learn more about iteration in python

# %%
##### What is the best way to drop non numerica columns from the dataframe

# %%
Data.dtypes
# Out:
# Row_ID             int64
# Order_ID          object
# Order_Date        object
# Ship_Date         object
# Ship_Mode         object
# Customer_ID       object
# Customer_Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal_Code        int64
# Region            object
# Product_ID        object
# Category          object
# Sub-Category      object
# Product_Name      object
# Profit           float64
# Location          object
# dtype: object

# %%
Data1.select_dtypes(include='number').dtypes

### To select only numeric column from the dataframe, read more about in the help
# Out:
# Row ID           int64
# Postal Code      int64
# Sales          float64
# Quantity         int64
# Discount       float64
# Profit         float64
# dtype: object

# %% [markdown]
# ##### <h3><u><font color='DodgerBlue '><b>Chapter:---------> 10 How do i use the "axis" Parameter in Pandas</b></font></h3></u>

# %%
Data1.describe(include=['int64'])

### Describe method with include argument
# Out:
#             Row ID   Postal Code     Quantity
# count  9994.000000   9994.000000  9994.000000
# mean   4997.500000  55190.379428     3.789574
# std    2885.163629  32063.693350     2.225110
# min       1.000000   1040.000000     1.000000
# 25%    2499.250000  23223.000000     2.000000
# 50%    4997.500000  56430.500000     3.000000
# 75%    7495.750000  90008.000000     5.000000
# max    9994.000000  99301.000000    14.000000

# %%
Data.columns
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Profit', 'Location'],
#       dtype='object')

# %%
Data.drop('Category',axis=1).head(2)

## Axis parameter use to identity rows or column, Axis=1 means Column and Axis=0 means Row
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class    DV-13045
# 3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal_Code Region       Product_ID Sub-Category  \
# 2        90036   West  OFF-LA-10000240       Labels
# 3        33311  South  FUR-TA-10000577       Tables
#
#                                         Product_Name    Profit  \
# 2  Self-Adhesive Address Labels for Typewriters b...    6.8714
# 3      Bretford CR4500 Series Slim Rectangular Table -383.0310
#
#                    Location
# 2   Los Angeles, California
# 3  Fort Lauderdale, Florida

# %%
Data.drop(index=[2,5],axis=0).head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 6       7  CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
# 7       8  CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
# 8       9  CA-2014-115812  09-06-2014  14-06-2014  Standard Class    BH-11710
#
#      Customer_Name   Segment        Country             City       State  \
# 3   Sean O'Donnell  Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell  Consumer  United States  Fort Lauderdale     Florida
# 6  Brosina Hoffman  Consumer  United States      Los Angeles  California
# 7  Brosina Hoffman  Consumer  United States      Los Angeles  California
# 8  Brosina Hoffman  Consumer  United States      Los Angeles  California
#
# ...

# %%
Data.select_dtypes(include=['number']).min(axis='index')
# Out:
# Row_ID            3.000
# Postal_Code    1040.000
# Profit        -6599.978
# dtype: float64

# %%
Data.dropna().shape

#### Docstring:Remove missing values.

#### See the :ref:`User Guide <missing_data>` for more on which values are considered missing, and how to work with missing data.
# Out:
# (9992, 19)

# %%
Data.dtypes

### Fill NA/NaN values using the specified method.
# Out:
# Row_ID             int64
# Order_ID          object
# Order_Date        object
# Ship_Date         object
# Ship_Mode         object
# Customer_ID       object
# Customer_Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal_Code        int64
# Region            object
# Product_ID        object
# Category          object
# Sub-Category      object
# Product_Name      object
# Profit           float64
# Location          object
# dtype: object

# %%
import streamlit as st
import pandas as pd
import plotly.express as px
import os
import warnings
warnings.filterwarnings('ignore')

# %%
#st.set_page_config(page_title="SuperStore!!!",page_icon=":bar:chart:",layout="wide")
#st.title(" :bar_chart: Sample SuperStore EDA")

# %%
#!streamlit run test.py

# %%
#!streamlit config show
#192.168.0.192

# %%
#!pip install --upgrade streamlit==0.63.0

# %%
#!pip install --upgrade "protobuf<=3.20.1"

# %%
#!pip uninstall click

# %%
#!pip install click==8.0.4

# %%
#!pip uninstall click --yes

# %%
#!pip install click==8.0.4

# %%
Data1.shape
# Out:
# (9994, 21)

# %% [markdown]
# ## Dash and ployly

# %%
#import dash
#import dash_core_components as dcc
#import dash_html_components as html

# %%
#app=dash.Dash()

# %%
#app.layout=html.Div([
    
   # html.H1('Hello Dash!!!'),
    #html.Div('Dash ---- A Data Product development framework for plotly')
#])

# %%
#if __name__=='__main__':
  # app.run_server(port=8080)

# %%
#!streamlit hello --server.headless=true

# %%
Data1.shape
# Out:
# (9994, 21)

# %% [markdown]
# ##### <h3><u><font color='DodgerBlue '><b>Chapter:---------> 11  How do i use string method in Pandas</b></font></h3></u>

# %%
## there are many string method in pandas
'hello'.upper()
# Out:
# 'HELLO'

# %%
'HELLO'.lower()
# Out:
# 'hello'

# %%
Data1.head(2)
# Out:
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2016  11-11-2016  Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2016  11-11-2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
#### Suppose we want to make Customer name in upper case

Data1['Customer Name'].str.upper()
# Out:
# 0            CLAIRE GUTE
# 1            CLAIRE GUTE
# 2        DARRIN VAN HUFF
# 3         SEAN O'DONNELL
# 4         SEAN O'DONNELL
#               ...
# 9989    TOM BOECKENHAUER
# 9990         DAVE BROOKS
# 9991         DAVE BROOKS
# 9992         DAVE BROOKS
# 9993        CHRIS CORTES
# Name: Customer Name, Length: 9994, dtype: object

# %%
### What is want to search a specific value in the series using str

Data1[Data1['Customer Name'].str.contains('Dave Brooks')].head(2)
# Out:
#      Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 157     158  CA-2014-104269  01-03-2014  06-03-2014  Second Class    DB-13060
# 433     434  CA-2016-127369  06-06-2016  07-06-2016   First Class    DB-13060
#
#     Customer Name   Segment        Country     City  ... Postal Code  Region  \
# 157   Dave Brooks  Consumer  United States  Seattle  ...       98115    West
# 433   Dave Brooks  Consumer  United States   Lowell  ...        1852    East
#
#           Product ID         Category Sub-Category  \
# 157  FUR-CH-10004063        Furniture       Chairs
# 433  OFF-ST-10003306  Office Supplies      Storage
#
#                                 Product Name    Sales  Quantity  Discount  \
# 157  Global Deluxe High-Back Manager's Chair  457.568         2       0.2
# 433                         Letter Size Cart  714.300         5       0.0
#
#        Profit
# 157   51.4764
# 433  207.1470
#
# [2 rows x 21 columns]

# %%
### what is we want to replace something from the pandas series

Data1['Customer ID'].str.replace('-','__').str.replace('__','/')
# Out:
# 0       CG/12520
# 1       CG/12520
# 2       DV/13045
# 3       SO/20335
# 4       SO/20335
#           ...
# 9989    TB/21400
# 9990    DB/13060
# 9991    DB/13060
# 9992    DB/13060
# 9993    CC/12220
# Name: Customer ID, Length: 9994, dtype: object

# %%
#### what is Regular expression A RegEx, or Regular Expression, is a sequence of characters that forms 
#### a search pattern. 
#### RegEx can be used to check if a string contains the specified ...

# %% [markdown]
# ##### <h3><u><font color='Navy '><b>Chapter:---------> 12  How do i change data type of the pandas series</b></font></h3></u>

# %%
Data1.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
Data1['Row ID'].astype('float64').dtypes
# Out:
# dtype('float64')

# %%
### In order to do math on the columns which are are described as string need to be converted 

Data1.head(2)
# Out:
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2016  11-11-2016  Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2016  11-11-2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
### what is you want to replace a $ sign from pandas series and converted into float and find out mean

### Data1.Profit.str.replace('',' ').astype('float').mean()

# %%
### 
Data.Region.str.contains('South').astype(int).head()
# Out:
# 2    0
# 3    1
# 4    1
# 5    0
# 6    0
# Name: Region, dtype: int64

# %%
Data1.Region.unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
Data1.Region.replace(['South','West','Central','East'],[1,2,3,4],inplace=True)

# %%
print(Data1.head())
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class    DV-13045
# 3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
Data1.Region.replace()
# Out:
# 0       1
# 1       1
# 2       2
# 3       1
# 4       1
#        ..
# 9989    1
# 9990    2
# 9991    2
# 9992    2
# 9993    2
# Name: Region, Length: 9994, dtype: int64

# %%
Data1.describe(include='object')
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# count             9994        9994        9994            9994        9994
# unique            5009        1237        1334               4         793
# top     CA-2017-100111  05-09-2016  16-12-2015  Standard Class    WB-21850
# freq                14          38          35            5968          37
#
#         Customer Name   Segment        Country           City       State  \
# count            9994      9994           9994           9994        9994
# unique            793         3              1            531          49
# top     William Brown  Consumer  United States  New York City  California
# freq               37      5191           9994            915        2001
#
#              Product ID         Category Sub-Category     Product Name
# count              9994             9994         9994             9994
# unique             1862                3           17             1850
# ...

# %% [markdown]
# ##### <h3><u><font color='DarkSalmon '><b>Chapter:---------> 13  When should i use GROUPBY in pandas</b></font></h3></u>

# %%
Data1.head(3)
# Out:
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2016  11-11-2016  Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2016  11-11-2016  Second Class    CG-12520
# 2       3  CA-2016-138688  12-06-2016  16-06-2016  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
#
#    Region       Product ID         Category Sub-Category  \
# 0       1  FUR-BO-10001798        Furniture    Bookcases
# 1       1  FUR-CH-10000454        Furniture       Chairs
# 2       2  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# ...

# %%
Data1.groupby('Segment').Sales.std()
# Out:
# Segment
# Consumer       585.516175
# Corporate      599.410408
# Home Office    755.516379
# Name: Sales, dtype: float64
